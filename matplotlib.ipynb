# %% [markdown]
# <span style="font-size: 50px; color: green;">**Pyplot**</span>
#
#
# Most of the Matplotlib utilities lies under the **pyplot** submodule, and are usually imported under the **plt** alias:
#
#
# **plot**
#
# **scatter**
#
# **hist**
#
# **bar**
#
# **pie**

# %%
# import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
xpoints = np.array([0, 6])   # CREATE A ARRAY 
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints) # PLOT WITH ARRUMENT
plt.show() # SHOW KRANE KE LIYE

# %% [markdown]
#       Plotting x and y points
# The **plot()** function is used to draw points (markers) in a diagram.
#
# By default, the plot() function draws a line from point to point.
#
# The function takes parameters for specifying points in the diagram.
#
# Parameter 1 is an array containing the points on the x-axis.
#
# Parameter 2 is an array containing the points on the y-axis.
#
# If we need to plot a line from (1, 3) to (8, 10), we have to pass two arrays [1, 8] and [3, 10] to the plot function.

# %% [markdown]
#       Plotting Without Line
# To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'.

# %%
# import matplotlib.pyplot as plt
# import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'H')
plt.show()

# %% [markdown]
# **Matplotlib Markers**

# %%
# You can use the keyword argument marker to emphasize each point with a specified marker:
xpoints = np.array([1, 8])
# ypoints = np.array([3, 10])

plt.plot(xpoints, marker= 'o')
plt.show()

# %%
xpoints = np.array([1, 8,4,5])
# ypoints = np.array([3, 10])

plt.plot(xpoints, marker= 'o')
plt.show()

# %%
xpoints = np.array([1, 8,4,5])
# ypoints = np.array([3, 10])

plt.plot(xpoints, marker= '*')
plt.show()

# %%
xpoints = np.array([1, 8,4,5])
# ypoints = np.array([3, 10])

plt.plot(xpoints, 'o:b')   #o:r is denote of dot line  r is denote of color 
plt.show()

# %% [markdown]
# **Marker Size**
# You can use the keyword argument *markersize* or the shorter version, *ms* to set the size of the markers:

# %%
xpoints = np.array([1, 8,4,5])
# ypoints = np.array([3, 10])

plt.plot(xpoints,marker = '*', ms = 30)   # ms is reduce of point size 
plt.show()

# %%
xpoints = np.array([1, 8,4,5])
# ypoints = np.array([3, 10])

plt.plot(xpoints,marker = '*', ms = 30,mec='r' )   # boundery 
plt.show()

# %%
xpoints = np.array([1, 8,4,5])
# ypoints = np.array([3, 10])

plt.plot(xpoints,marker = '*', ms = 30,mfc='r' )   # inerr fill clour  
plt.show()

# %% [markdown]
# **_Linestyle_**
#
# You can use the keyword argument *linestyle*, or shorter *ls*, to change the style of the plotted line:

# %%
xpoints = np.array([1, 8,4,5])
# ypoints = np.array([3, 10])

plt.plot(xpoints,ls = 'dotted' )   # inerr fill clour  
plt.show()

# %%
plt.plot(ypoints, linestyle = '-.')

# %% [markdown]
# **Shorter Syntax**
#
#
#
# The line style can be written in a shorter syntax:
#
# linestyle can be written as ls.
#
# dotted can be written as :.
#
# dashed can be written as --.

# %% [markdown]
# **Line Width**
#
#
# You can use the keyword argument *linewidth* or the shorter lw to change the width of the line.
#
# The value is a floating number, in points

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# **Multiple Lines**
#
# You can plot as many lines as you like by simply adding more **plt.plot()** functions:

# %%
ypoints = np.array([3, 8, 1, 10])
xpoints = np.array([2,5,8,4])

plt.plot(ypoints)
plt.plot(xpoints)
plt.show()

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 4, 5])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1)
plt.plot(x2)
plt.show()

# %% [markdown]
# **Create Labels for a Plot**
#
#
# With Pyplot, you can use the *xlabel()* and *ylabel()* functions to set a label for the x- and y-axis.

# %%
ypoints = np.array([3, 8, 1, 10])
xpoints = np.array([3, 6, 4, 10])

plt.xlabel("x vale point")
plt.ylabel("y vale point")
plt.plot(ypoints, xpoints,linewidth = '20.5')
plt.show()

# %% [markdown]
# **Title**

# %%
ypoints = np.array([3, 8, 1, 10])
xpoints = np.array([3, 8, 1, 10])
plt.title("mateplote pd rhe hai bhaii",loc= "right")
plt.xlabel("tu x pe ja na ")
plt.ylabel("yha kya kr rhe ho bhaiii apni  postion pe jaoo")
plt.plot(ypoints,xpoints,linewidth = '20.5')

# %% [markdown]
# **Add Grid Lines to a Plot**
#
#
# With Pyplot, you can use the *grid()* function to add grid lines to the plot.

# %%
ypoints = np.array([3, 8, 1, 10])
xpoints = np.array([3, 8, 1, 10])
plt.title("mateplote pd rhe hai bhaii")
plt.xlabel("tu x pe ja na ")
plt.ylabel("yha kya kr rhe ho bhaiii apni  postion pe jaoo")
plt.grid(axis="x",color = "green",linestyle="--",linewidth ="1")
plt.plot(ypoints,xpoints,linewidth = '20.5')

# %% [markdown]
# **Display Multiple Plots**
#
# With the **subplot()** function you can draw multiple plots in one figure:

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1) 
plt.title("first plot") #the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)  #the figure has 1 row, 2 columns, and this plot is the first plot.
plt.plot(x,y)

plt.suptitle("main figure")
plt.show()

# %% [markdown]
# ### Matplotlib Scatter
#
# **Creating Scatter Plots**
#
# With Pyplot, you can use the *scatter()* function to draw a scatter plot.
#
# The *scatter()* function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# **Compare Plots**

# %%
#one two, the age and speed of 15 cars:

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# **Color Each Dot**

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %% [markdown]
# **Size**

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes , marker= "*")

plt.show()

# %%
# Alpha
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes,marker="*",alpha=0.3)

plt.show()

# %% [markdown]
# **Combine Color Size and Alpha**
#
# You can combine a colormap with different sizes of the dots. This is best visualized if the dots are transparent:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y,  c = colors,s=sizes,marker="*")

plt.show()

# %%
#  cmap='nipy_spectral'
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y,  c = colors,s=sizes,alpha=0.5,cmap='Accent')
# plt.colorbar()  ## function 
plt.colorbar(label = "colour map")
plt.show()
# Out:
# C:\Users\Jai\AppData\Local\Temp\ipykernel_12240\3849599637.py:6: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y,  c = colors,s=sizes,alpha=0.5,cmap='Accent')

# %% [markdown]
# ### Matplotlib Bars

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x,y,height=0.1)  #horigontal
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,color ='red')
plt.show()

# %% [markdown]
# **Bar Width**
#
#
# The bar() takes the keyword argument width to set the *width* of the bars:

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y,color ='red',width=0.1)
plt.show()

# %% [markdown]
# ### Matplotlib Histograms
#
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.
#
# Example: Say you ask for the height of 250 people, you might end up with a histogram like this:
#
#
#                 Create Histogram
#
#
# In Matplotlib, we use the hist() function to create histograms.
#
# The hist() function will use an array of numbers to create a histogram, the array is sent into the function as an argument.

# %%
x = np.random.normal(170, 10, 250)

print(x)
# Out:
# [160.54553566 165.00401625 159.59376717 154.98468511 176.47811541
#  170.3440565  183.99944408 144.21130187 192.65575241 179.29093118
#  176.71866731 179.8544989  182.94082347 166.06246283 152.57683866
#  163.8085221  171.54474239 172.11895674 172.56254581 155.85256773
#  163.94577064 174.95932252 173.083888   163.99457602 169.02861593
#  180.80341475 161.78885586 161.99283386 179.9786228  151.13809205
#  177.16007695 190.72524491 187.58375569 160.9387922  169.28777366
#  182.43814309 168.56475833 174.62693039 190.08820211 183.55971931
#  162.16548017 174.77596625 173.60850287 187.8734455  168.05870355
#  158.95776814 168.94916769 170.9038507  178.41503056 167.55046722
#  181.29094367 166.60654014 168.72903616 151.03364598 175.02033475
#  168.85609451 184.71160732 159.70643108 192.69052787 181.7733466
#  183.03209152 182.42629816 168.30173973 160.38723041 188.62418244
#  179.48088522 163.28282447 166.38730656 168.48435429 182.62986929
# ...

# %%
x 
plt.hist(x)
# Out:
# (array([ 1.,  2.,  9., 18., 47., 49., 50., 43., 18., 13.]),
#  array([134.72073367, 140.58477659, 146.4488195 , 152.31286241,
#         158.17690533, 164.04094824, 169.90499115, 175.76903406,
#         181.63307698, 187.49711989, 193.3611628 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Matplotlib Pie Charts
#
# With Pyplot, you can use the pie() function to draw pie charts:

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 100)
plt.show()

# %% [markdown]
# **Explode**
#
# Maybe you want one of the wedges to stand out? The explode parameter allows you to do that.
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed:

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2,0,0,10]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# **shadonw**

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2,0,0,0]

plt.pie(y, labels = mylabels, explode = myexplode,shadow=True)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]
sizes = [10,20,30,40]

plt.pie(sizes,y, labels = mylabels, colors = mycolors)
plt.show()

# %% [markdown]
# **Legend**
#
# To add a list of explanation for each wedge, use the legend() function:

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# **Legend With Header**

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %%
df = pd.read_csv(r'C:\Users\Jai\Desktop\LIT\Lit\Used_Bikes.csv')
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
plt.scatter(df["age"],df["price"])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("D:\\Python\\Articles\\matplotlib\\sales_data.csv")
monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()

plt.plot(monthList, faceCremSalesData,   label = 'Face cream Sales Data', marker='o', linewidth=3)
plt.plot(monthList, faceWashSalesData,   label = 'Face Wash Sales Data',  marker='o', linewidth=3)
plt.plot(monthList, toothPasteSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(monthList, bathingsoapSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(monthList, shampooSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(monthList, moisturizerSalesData, label = 'ToothPaste Sales Data', marker='o', linewidth=3)

plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
plt.show()

# %%
x = [1,2,3,4]
y = [5,6,7,8]
labels = ["A","B","c","D"]
plt.plot(x,y)
plt.xticks(x , labels)
plt.savefig("graph.png")
plt.show()

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 8]
errors = [0.5, 0.7, 0.3, 0.8]

plt.bar(categories, values, yerr=errors, capsize=5)
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart with Error Bars')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [10, 100, 1000])
plt.yscale('log')
plt.xlabel('X-axis')
plt.ylabel('Y-axis (log scale)')
plt.title('Logarithmic Scale Example')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y1 = [10, 20, 25, 30]
y2 = [30, 25, 20, 10]

line1, = plt.plot(x, y1, label='Line 1')
line2, = plt.plot(x, y2, label='Line 2')

first_legend = plt.legend(handles=[line1], loc='upper left')
ax = plt.gca().add_artist(first_legend)  # Add first legend manually

plt.legend(handles=[line2], loc='upper right')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Multiple Legends in a Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
categories = ['A', 'B', 'C', 'D']
values1 = [5, 7, 3, 8]
values2 = [6, 3, 9, 2]

# Number of categories
N = len(categories)

# X-axis positions
ind = np.arange(N)
width = 0.35

# Create bar chart
fig, ax = plt.subplots()
bar1 = ax.bar(ind, values1, width, label='Dataset 1')
bar2 = ax.bar(ind + width, values2, width, label='Dataset 2')

# Add labels, title, and legend
ax.set_xlabel('Category')
ax.set_ylabel('Values')
ax.set_title('Grouped Bar Chart')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(categories)
ax.legend()

plt.show()
